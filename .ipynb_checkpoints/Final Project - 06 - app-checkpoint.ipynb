# %% [markdown]
# # App

# %%
import numpy as np
import pandas as pd
from sklearn import neighbors
from sklearn.model_selection import train_test_split

# Assign %pwd to working_dir
working_dir = %pwd

def knn_classifier():
    spotify = pd.read_csv( (working_dir)+'/Data/spotify-classlabels-kmeans.csv', delimiter=",")
    target_labels = spotify['cluster']
    spotify = spotify.drop(columns=['cluster'])

    train, test, target_train, target_test = train_test_split(spotify, target_labels, test_size=0.2, random_state=33)

    pca_names = np.array(
        ['mode_0',
         'acousticness',
         'explicit_1',
         'instrumentalness',
         'key',
         'valence'])
    train_numeric = train[pca_names]

    n_neighbors = 37
    knn_classifier = neighbors.KNeighborsClassifier(n_neighbors)
    knn_classifier.fit(train_numeric, target_train)

    return knn_classifier


create_new_playlist = "y"

while create_new_playlist == "y":
    print("""
    ********************************************************************************************************
    Welcome to the Playlist generator using song data from Spotify. First, choose your method of clustering:
    ******************************************************************************************************** 
    """)
    print("""
                What cluster model would you like to use? 
                (1) kmeans with PCA
                (2) kmeans without PCA
                (3) DBSCAN with PCA
                (4) DBSCAN without PCA
                """)
    cluster_method = input("Enter cluster method, or press enter with no number for default=KMeans with PCA: ")

    if cluster_method == '1' or cluster_method == "":
        spotify = pd.read_csv((working_dir)+'/Data/spotify-classlabels-kmeans.csv', delimiter=",")
    elif cluster_method == '2':
        spotify = pd.read_csv((working_dir)+'/Data/spotify-classlabels-kmeans-without_pca.csv', delimiter=",")
    elif cluster_method == '3':
        spotify = pd.read_csv((working_dir)+'/Data/spotify-classlabels-DBSCAN.csv', delimiter=",")
    elif cluster_method == '4':
        spotify = pd.read_csv((working_dir)+'/Data/spotify-classlabels-DBSCAN-without_pca.csv', delimiter=",")

    sample = spotify.sample(10)
    sample = sample[['artists', 'name', 'year', 'cluster']]
    print("Do you want to generate playlist based on an existing song, or enter your own? default=existing")
    own_or_existing = input("(n) for new song, (e) for existing: ")

    if own_or_existing == 'e' or own_or_existing == "":

        print("""
        Choose the song by entering corresponding number from the following list which will be used 
        to generate playlist of similar songs, (enter) to see new list, (q) to quit.
        (Note- using your own song will only use the default=KMeans with PCA clusters for the classification)
        """)
        user_input = None

        while user_input != 'q':
            for i in range(0, 10):
                print(f"""
                ({i})
                Artist: {sample.iloc[i].artists}
                Song: {sample.iloc[i]['name']}
                Decade: {sample.iloc[i].year}
                """)

            user_input = input("Enter song number (or n to input your own song): ")

            if user_input == "":
                sample = spotify.sample(10)
                sample = sample[['artists', 'name', 'year']]
                continue

            elif user_input in '0123456789':
                user_input = int(user_input)
                pd.set_option('display.expand_frame_repr', False)

                playlist = spotify.loc[spotify['cluster'] == sample.iloc[user_input].cluster].sample(20)
                playlist = playlist.reset_index()
                print("""
                PLAYLIST
                -------------------------------------------------------------------------------------------------------""")
                print(playlist[['artists', 'name', 'year']])
                create_new_playlist = input("Create new playlist? (y/n)")
                break

    elif own_or_existing == 'n':
        spotify = pd.read_csv((working_dir)+'/Data/spotify-classlabels-kmeans.csv', delimiter=",")
        name = input("Song name: ")
        artist = input("Artist: ")
        mode = input("Major (1) or minor (0): ")
        acousticness = input("Level of acousticness (from 0-1): ")
        explicit = input("Explicit content (1) or not (0): ")
        instrumentalness = input("Level of instrumentalness (from 0-1): ")
        key = input("Key (approximate from 0-1 where C is 0 and B is 1, i.e C#=.09): ")
        valence = input("Valence (musical happiness level): ")
        # here is where we put the knn classifier to work
        df = pd.DataFrame({
            "mode_0": [int(mode)],
            "acousticness": [float(acousticness)],
            "explicit_1": [int(explicit)],
            "instrumentalness": [float(instrumentalness)],
            "key": [float(key)],
            "valence": [float(valence)]
        })
        knn_clf = knn_classifier()
        prediction = knn_clf.predict(df)
        print(prediction)
        playlist = spotify.loc[spotify['cluster'] == prediction[0]].sample(20)
        playlist = playlist.reset_index()
        pd.set_option('display.expand_frame_repr', False)
        print(playlist[['artists', 'name', 'year']])

        create_new_playlist = input("Create new playlist? (y/n)")


print("Exiting program...")
# Out:
#     ********************************************************************************************************
#     Welcome to the Playlist generator using song data from Spotify. First, choose your method of clustering:
#     ********************************************************************************************************
#
#
#                 What cluster model would you like to use?
#                 (1) kmeans with PCA
#                 (2) kmeans without PCA
#                 (3) DBSCAN with PCA
#                 (4) DBSCAN without PCA
#
# Enter cluster method, or press enter with no number for default=KMeans with PCA:
# Do you want to generate playlist based on an existing song, or enter your own? default=existing
# (n) for new song, (e) for existing:
#
#         Choose the song by entering corresponding number from the following list which will be used
#         to generate playlist of similar songs, (enter) to see new list, (q) to quit.
#         (Note- using your own song will only use the default=KMeans with PCA clusters for the classification)
#
#
#                 (0)
#                 Artist: ['The Notorious B.I.G.']
#                 Song: One More Chance / Stay with Me - Remix; 2007 Remaster
#                 Decade: 2000s
#
#
#                 (1)
#                 Artist: ['Francisco Canaro', 'Ada Falcón']
#                 Song: Midinette - Remasterizado
#                 Decade: 1920s
#
#
#                 (2)
#                 Artist: ['Kostas Roukounas']
#                 Song: H korh tou pappa
#                 Decade: 1930s
#
#
#                 (3)
#                 Artist: ['Lady A']
#                 Song: I Run To You
#                 Decade: 2000s
#
#
#                 (4)
#                 Artist: ['Lata Mangeshkar']
#                 Song: Rasik Balma Se Dil Kyon Lagaya
#                 Decade: 1950s
#
#
#                 (5)
#                 Artist: ['Bone Thugs-N-Harmony']
#                 Song: Body Rott
#                 Decade: 1990s
#
#
#                 (6)
#                 Artist: ['Ruby Smith', 'Jimmy Johnson']
#                 Song: Backwater Blues - Live
#                 Decade: 1920s
#
#
#                 (7)
#                 Artist: ['Kleeer']
#                 Song: Tonight
#                 Decade: 1980s
#
#
#                 (8)
#                 Artist: ['Francisco Canaro', 'Roberto Maida']
#                 Song: No Hay Que Hacerse Mala Sangre - Remasterizado
#                 Decade: 1930s
#
#
#                 (9)
#                 Artist: ['Luke Bryan']
#                 Song: That's My Kind Of Night
#                 Decade: 2010s
#
# Enter song number (or n to input your own song): 0
#
#                 PLAYLIST
#                 -------------------------------------------------------------------------------------------------------
#                                               artists                                               name   year
# 0        ['Black Star', 'Jane Doe', 'Punch', 'Words']                                Twice Inna Lifetime  1990s
# 1                              ['Trey Songz', 'T.I.']                             2 Reasons (feat. T.I.)  2010s
# 2              ['Bad Bunny', 'Diplo', 'Nitti Gritti']                                            200 Mph  2010s
# 3                                   ['Crucial Dudes']                            61 Penn (2021 Remaster)  2020s
# 4                        ['2 Chainz', 'Travis Scott']                                               4 AM  2010s
# 5                                      ['Bryce Vine']                                    Sour Patch Kids  2010s
# 6                              ['KYLE', 'Lil Yachty']                            iSpy (feat. Lil Yachty)  2010s
# 7                                       ['Cream Pie']                                      Love Is Blind  2010s
# 8                               ['Эрих Мария Ремарк']                         Часть 28.4 - Обратный путь  1930s
# 9                                     ['i.am.orange']                                     bawo (3-19-18)  2010s
# 10                                           ['2Pac']                                    Part Time Mutha  1990s
# 11                                       ['Lil Peep']                                          Cry Alone  2010s
# 12                 ['Trick Daddy', 'Jaheim', 'Trina']                   Tonight (feat. Jaheim and Trina)  2000s
# 13                               ['Эрнест Хемингуэй']             Часть 48.2 - За рекой, в тени деревьев  1950s
# 14  ['Macklemore', 'Ryan Lewis', 'Hollis', 'ScHool...           White Walls (feat. ScHoolboy Q & Hollis)  2010s
# 15                                         ['Staind']                                            For You  2000s
# 16  ['Snoop Dogg', 'The Lady Of Rage', 'Tha Dogg P...  For All My Niggaz And Bitches (feat. Tha Dogg ...  1990s
# 17                                 ['2Pac', 'Talent']                                            Changes  1990s
# 18                               ['Эрнест Хемингуэй']                 Часть 85.2 - По ком звонит колокол  1940s
# 19                            ['The Stupors Arizona']                   Tilt My Girl on the Tilt-a-Whirl  2020s
# Create new playlist? (y/n)y
#
#     ********************************************************************************************************
#     Welcome to the Playlist generator using song data from Spotify. First, choose your method of clustering:
#     ********************************************************************************************************
#
#
#                 What cluster model would you like to use?
#                 (1) kmeans with PCA
#                 (2) kmeans without PCA
#                 (3) DBSCAN with PCA
#                 (4) DBSCAN without PCA
#
# Enter cluster method, or press enter with no number for default=KMeans with PCA: 1
# Do you want to generate playlist based on an existing song, or enter your own? default=existing
# (n) for new song, (e) for existing: n
# Song name: Song
# Artist: Artist
# Major (1) or minor (0): 1
# Level of acousticness (from 0-1): .90
# Explicit content (1) or not (0): 0
# Level of instrumentalness (from 0-1): .80
# Key (approximate from 0-1 where C is 0 and B is 1, i.e C#=.09): .15
# Valence (musical happiness level): .90
# [8]
#                                               artists                                               name   year
# 0                                  ['Jackie Gleason']                                        Deep Purple  1950s
# 1                            ['Windham Hill Artists']                                 Carol of the Bells  1990s
# 2   ['Giorgos Papasideris', 'Giorgos', 'Anestopoyl...                                  Mikri Vasilikoyla  1940s
# 3                      ['Egyptian Meditation Temple']                              Entering the New Year  2010s
# 4   ['Al Di Meola', 'John McLaughlin', 'Paco de Lu...  Short Tales of the Black Forest - Live at Warf...  1980s
# 5                                ['Kostas Roukounas']                                    Tampaxaniotikos  1940s
# 6                                  ['Howard Roberts']                              Relaxin' At Camarillo  1950s
# 7   ['Άννα Μπέλλα', 'Ιωάννης Τατασόπουλος', 'Giorg...                                      Οι μπατήρηδες  1950s
# 8                                     ['Marvin Gaye']                                       Funky Nation  1970s
# 9                                 ['Sulochana Kadam']                                  Firakh Mein Guzri  1940s
# 10                                   ['Rita Ampatzi']                              Steile amaksi pare me  1930s
# 11  ['Pyotr Ilyich Tchaikovsky', 'Sir Simon Rattle...  Tchaikovsky: The Nutcracker, Op. 71, Act 2: No...  2010s
# 12                               ['Francisco Canaro']                              Bijou - Remasterizado  1920s
# 13                                      ['Stan Getz']                              Lover Come Back To Me  1950s
# 14  ['Johann Strauss II', 'Riccardo Muti', 'Wiener...                  Frühlingsstimmen, Walzer, Op. 410  2020s
# 15                                       ['Lowtails']                                          Walkingly  2020s
# 16                               ['ANTONIS NTALGKAS']                         Ego eimai enos psara paidi  1930s
# 17                                  ['John Coltrane']            Do I Love You Because You're Beautiful?  1960s
# 18                                  ['Antonio Morel']                                           Merengue  1930s
# 19                                    ['Marvin Gaye']                                   Cleo's Apartment  1970s
