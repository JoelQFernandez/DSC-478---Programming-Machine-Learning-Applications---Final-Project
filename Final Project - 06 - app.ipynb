# %% [markdown]
# # App

# %%
import numpy as np
import pandas as pd
from sklearn import neighbors
from sklearn.model_selection import train_test_split

# Assign %pwd to working_dir
working_dir = %pwd

def knn_classifier():
    spotify = pd.read_csv( (working_dir)+'/Data/spotify-classlabels-kmeans.csv', delimiter=",")
    target_labels = spotify['cluster']
    spotify = spotify.drop(columns=['cluster'])

    train, test, target_train, target_test = train_test_split(spotify, target_labels, test_size=0.2, random_state=33)

    pca_names = np.array(
        ['mode_0',
         'acousticness',
         'explicit_1',
         'instrumentalness',
         'key',
         'valence'])
    train_numeric = train[pca_names]

    n_neighbors = 37
    knn_classifier = neighbors.KNeighborsClassifier(n_neighbors)
    knn_classifier.fit(train_numeric, target_train)

    return knn_classifier


create_new_playlist = "y"

while create_new_playlist == "y":
    print("""
    ********************************************************************************************************
    Welcome to the Playlist generator using song data from Spotify. First, choose your method of clustering:
    ******************************************************************************************************** 
    """)
    print("""
                What cluster model would you like to use? 
                (1) kmeans with PCA
                (2) kmeans without PCA
                (3) DBSCAN with PCA
                (4) DBSCAN without PCA
                """)
    cluster_method = input("Enter cluster method: ")

    if cluster_method == '1':
        spotify = pd.read_csv((working_dir)+'/Data/spotify-classlabels-kmeans.csv', delimiter=",")
    elif cluster_method == '2':
        spotify = pd.read_csv((working_dir)+'/Data/spotify-classlabels-kmeans-without_pca.csv', delimiter=",")
    elif cluster_method == '3':
        spotify = pd.read_csv((working_dir)+'/Data/spotify-classlabels-DBSCAN.csv', delimiter=",")
    elif cluster_method == '4':
        spotify = pd.read_csv((working_dir)+'/Data/spotify-classlabels-DBSCAN-without_pca.csv', delimiter=",")

    sample = spotify.sample(10)
    sample = sample[['artists', 'name', 'year', 'cluster']]
    print("Do you want to generate playlist based on an existing song, or enter your own?")
    own_or_existing = input("(n) for new song, (e) for existing: ")

    if own_or_existing == 'e':

        print("""
        Choose the song by entering corresponding number from the following list which will be used 
        to generate playlist of similar songs, (l) to see new list, (q) to quit.
        (Note- using your own song will only use kmeans with PCA clusters for the classification)
        """)
        user_input = None

        while user_input != 'q':
            for i in range(0, 10):
                print(f"""
                ({i})
                Artist: {sample.iloc[i].artists}
                Song: {sample.iloc[i]['name']}
                Decade: {sample.iloc[i].year}
                """)

            user_input = input("Enter song number (or n to input your own song): ")

            if user_input == 'l':
                sample = spotify.sample(10)
                sample = sample[['artists', 'name', 'year']]
                continue

            elif user_input in '0123456789':
                user_input = int(user_input)
                pd.set_option('display.expand_frame_repr', False)

                playlist = spotify.loc[spotify['cluster'] == sample.iloc[user_input].cluster].sample(20)
                playlist = playlist.reset_index()
                print("""
                PLAYLIST
                -------------------------------------------------------------------------------------------------------""")
                print(playlist[['artists', 'name', 'year']])
                create_new_playlist = input("Create new playlist? (y/n)")
                break

    elif own_or_existing == 'n':
        spotify = pd.read_csv((working_dir)+'/Data/spotify-classlabels-kmeans.csv', delimiter=",")
        name = input("Song name: ")
        artist = input("Artist: ")
        mode = input("Major (1) or minor (0): ")
        acousticness = input("Level of acousticness (from 0-1): ")
        explicit = input("Explicit content (1) or not (0): ")
        instrumentalness = input("Level of instrumentalness (from 0-1): ")
        key = input("Key (approximate from 0-1 where C is 0 and B is 1, i.e C#=.09): ")
        valence = input("Valence (musical happiness level): ")
        # here is where we put the knn classifier to work
        df = pd.DataFrame({
            "mode_0": [int(mode)],
            "acousticness": [float(acousticness)],
            "explicit_1": [int(explicit)],
            "instrumentalness": [float(instrumentalness)],
            "key": [float(key)],
            "valence": [float(valence)]
        })
        knn_clf = knn_classifier()
        prediction = knn_clf.predict(df)
        print(prediction)
        playlist = spotify.loc[spotify['cluster'] == prediction[0]].sample(20)
        playlist = playlist.reset_index()
        pd.set_option('display.expand_frame_repr', False)
        print(playlist[['artists', 'name', 'year']])

        create_new_playlist = input("Create new playlist? (y/n)")


print("Exiting program...")
# Out:
#     ********************************************************************************************************
#     Welcome to the Playlist generator using song data from Spotify. First, choose your method of clustering:
#     ********************************************************************************************************
#
#
#                 What cluster model would you like to use?
#                 (1) kmeans with PCA
#                 (2) kmeans without PCA
#                 (3) DBSCAN with PCA
#                 (4) DBSCAN without PCA
#
# Enter cluster method: 1
# Do you want to generate playlist based on an existing song, or enter your own?
# (n) for new song, (e) for existing: e
#
#         Choose the song by entering corresponding number from the following list which will be used
#         to generate playlist of similar songs, (l) to see new list, (q) to quit.
#         (Note- using your own song will only use kmeans with PCA clusters for the classification)
#
#
#                 (0)
#                 Artist: ['Francis Poulenc']
#                 Song: Suite française d'après Claude Gervaise, FP 80b: IV. Complainte
#                 Decade: 1940s
#
#
#                 (1)
#                 Artist: ['Los Enanitos Verdes']
#                 Song: Guitarras Blancas
#                 Decade: 1980s
#
#
#                 (2)
#                 Artist: ['Kraftwerk']
#                 Song: Spacelab - 2009 Remaster
#                 Decade: 1970s
#
#
#                 (3)
#                 Artist: ['Warren G']
#                 Song: And Ya Don't Stop
#                 Decade: 1990s
#
#
#                 (4)
#                 Artist: ['Asha Bhosle']
#                 Song: Ankhon Se Dilmen
#                 Decade: 1950s
#
#
#                 (5)
#                 Artist: ['Sonny Rollins']
#                 Song: There Is No Greater Love
#                 Decade: 1950s
#
#
#                 (6)
#                 Artist: ['Milton Rosenstock']
#                 Song: Just in Time (from Bells Are Ringing) - Vocal
#                 Decade: 1950s
#
#
#                 (7)
#                 Artist: ['El As De La Sierra']
#                 Song: Entre Perico Y Perico
#                 Decade: 1990s
#
#
#                 (8)
#                 Artist: ['Trasko', 'Robert Fulton']
#                 Song: New Years Day - Original Mix
#                 Decade: 2010s
#
#
#                 (9)
#                 Artist: ["King's X"]
#                 Song: Dogman
#                 Decade: 1990s
#
# Enter song number (or n to input your own song): 5
#
#                 PLAYLIST
#                 -------------------------------------------------------------------------------------------------------
#                                               artists                                               name   year
# 0                                       ['Manna Dey']                               Tu Pyar Ka Sagar Hai  1950s
# 1                                ['Francisco Canaro']                 Muchachita Porteña - Remasterizado  1940s
# 2   ['Kurt Weill', 'Helen Arden', 'Hope Emerson', ...             Street Scene: Ain't It Awful, the Heat  1940s
# 3                                       ['Perchicot']                        C'est La Mode Et Voila Tout  1920s
# 4                                   ['Joni Mitchell']  Intro To What's The Story Mr. Blue - Live at T...  2020s
# 5                                 ['The Marvelettes']                                       I Want A Guy  1960s
# 6            ['Monica Zetterlund', 'Bill Evans Trio']                             Jag Vet En Dejlig Rosa  1960s
# 7                                     ['Shanta Apte']                   Dekho Sakhiyan Kaisi Chhai Badri  1930s
# 8                                  ['Charlie Parker']                           Half Nelson - New Take 1  1950s
# 9                    ['George Enescu', 'Isaac Stern']  Violin Sonata No. 3 in A Minor, Op. 25 "Dans l...  1940s
# 10                                   ['Juan Gabriel']                               Yo No Nací para Amar  1980s
# 11                                    ['Bob Dorough']           Devil May Care - 2012 Remastered Version  1950s
# 12  ['Orchestre Piero Coppola', 'Lucy Perelli', 'P...  Carmen : Acte I - L'amour est enfant de bohème...  1920s
# 13                 ['Billie Holiday', 'Teddy Wilson']  It's Easy to Blame the Weather (with Teddy Wil...  1930s
# 14                                    ['Hugh Tracey']                          Bengeria - Kipsigis Tribe  1950s
# 15                                   ['Brenton Wood']                                     Two Time Loser  1960s
# 16                              ['Markos Vamvakaris']                              H ginaika mou zileuei  1930s
# 17             ['Los Peregrinos', 'Raul Shaw Moreno']                                  Borrachito Ladron  1950s
# 18                                    ['Neil Sedaka']                              Next Door to an Angel  1960s
# 19                                     ['India.Arie']                                     Ready For Love  2000s
# Create new playlist? (y/n)y
#
#     ********************************************************************************************************
#     Welcome to the Playlist generator using song data from Spotify. First, choose your method of clustering:
#     ********************************************************************************************************
#
#
#                 What cluster model would you like to use?
#                 (1) kmeans with PCA
#                 (2) kmeans without PCA
#                 (3) DBSCAN with PCA
#                 (4) DBSCAN without PCA
#
# Enter cluster method: 1
# Do you want to generate playlist based on an existing song, or enter your own?
# (n) for new song, (e) for existing: n
# Song name: whatever
# Artist: me
# Major (1) or minor (0): 1
# Level of acousticness (from 0-1): .007
# Explicit content (1) or not (0): 0
# Level of instrumentalness (from 0-1): .67
# Key (approximate from 0-1 where C is 0 and B is 1, i.e C#=.09): .50
# Valence (musical happiness level): .30
# [12]
#                               artists                                               name   year
# 0                  ['Herbie Hancock']                                          Butterfly  1970s
# 1              ['Onionz', 'Tim Cook']        Space Bass - Tim Cook Remix Remastered 2011  2010s
# 2                     ['Ace Ventura']                        Connected - Symphonix Remix  2010s
# 3                   ['Mercyful Fate']                                            Melissa  1980s
# 4                         ['D-wayne']                                             Modest  2010s
# 5                      ['The Meters']                                                Art  1960s
# 6       ['Holgi Star', 'Kaiserdisco']                       Defender - Kaiserdisco Remix  2010s
# 7                 ['Kool & The Gang']                                  Wild And Peaceful  1970s
# 8                            ['Ween']                         Waving My Dick in the Wind  1990s
# 9                ['Two Charming Men']                             Brusque - Original Mix  1920s
# 10                ['3Phazegenerator']                                         Inner Core  2010s
# 11                    ['Big Country']                                          Look Away  1980s
# 12                        ['Suicide']                                   Dream Baby Dream  1990s
# 13   ['DJ Caspa', 'Suzi Pink Rocket']                                       The Uppercut  2000s
# 14                        ['Galvino']                                              Laked  2010s
# 15  ['Chris Staropoli', 'Melanie S.']                       Reflections - Scot Cox Remix  2010s
# 16                         ['Notion']                                  Chute - 2014 edit  2010s
# 17                            ['Yes']  Five per Cent for Nothing - 2008 Remaster Vers...  1970s
# 18           ['Blood, Sweat & Tears']                                 Lucretia's Reprise  1970s
# 19           ['Stoneface & Terminal']                           Sidewinder - 2015 Rework  2010s
