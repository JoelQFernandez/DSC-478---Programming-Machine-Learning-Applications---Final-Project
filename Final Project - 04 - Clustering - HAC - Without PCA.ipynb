# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Assign %pwd to working_dir
working_dir = %pwd

# %%
spotify = pd.read_csv( (working_dir)+"/Data/spotify-pre_processed.csv", delimiter = ",")

# %%
# random sample the data
spotify_sample = spotify.sample(frac=0.1, random_state=3)
# remove nominal attributes
spotify_sample = spotify_sample[spotify_sample.describe().columns]
spotify_sample
# Out:
#         acousticness  danceability  duration_ms  energy  instrumentalness  \
# 16762         0.8360         0.569     0.025402  0.2890          0.000010
# 105509        0.2840         0.809     0.037504  0.4040          0.000000
# 88526         0.1730         0.559     0.028379  0.4440          0.000002
# 96876         0.9550         0.585     0.009254  0.2380          0.903000
# 48648         0.3740         0.530     0.039287  0.6910          0.111000
# ...              ...           ...          ...     ...               ...
# 11539         0.0671         0.641     0.038539  0.7800          0.001810
# 113371        0.9910         0.342     0.033119  0.0798          0.917000
# 66274         0.9190         0.200     0.037474  0.2280          0.000002
# 81698         0.9050         0.454     0.025622  0.2750          0.820000
# 54432         0.0155         0.541     0.052656  0.7900          0.000000
#
#              key  liveness  loudness  popularity  speechiness     tempo  \
# 16762   0.000000    0.2820  0.749636        0.19       0.0317  0.316233
# 105509  0.363636    0.1110  0.784152        0.51       0.0556  0.513488
# 88526   0.363636    0.2440  0.829269        0.44       0.0537  0.402793
# 96876   0.909091    0.1590  0.698771        0.00       0.0489  0.391052
# 48648   0.181818    0.2900  0.854921        0.41       0.0307  0.480668
# ...          ...       ...       ...         ...          ...       ...
# 11539   0.818182    0.0562  0.835095        0.56       0.0351  0.386962
# 113371  0.454545    0.1230  0.538752        0.00       0.0654  0.572899
# 66274   0.272727    0.2430  0.758187        0.32       0.0299  0.674872
# 81698   0.000000    0.1280  0.643145        0.21       0.0415  0.528983
# 54432   0.181818    0.3590  0.800908        0.62       0.0643  0.340820
#
#         valence  explicit_0  explicit_1  mode_0  mode_1
# 16762     0.369           1           0       0       1
# 105509    0.636           1           0       0       1
# 88526     0.684           1           0       0       1
# 96876     0.770           1           0       0       1
# 48648     0.581           1           0       0       1
# ...         ...         ...         ...     ...     ...
# 11539     0.746           1           0       0       1
# 113371    0.416           1           0       0       1
# 66274     0.203           1           0       0       1
# 81698     0.558           1           0       0       1
# 54432     0.732           1           0       0       1
#
# [17439 rows x 16 columns]

# %%
import scipy.cluster.hierarchy as shc

plt.figure(figsize=(10, 7))
plt.title("Spotify Dendograms")
dend = shc.dendrogram(shc.linkage(spotify_sample, method='ward'))
