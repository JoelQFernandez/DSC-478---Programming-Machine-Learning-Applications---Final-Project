# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
from sklearn import neighbors, tree, naive_bayes
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# %%
# Assign %pwd to working_dir
working_dir = %pwd

# %%
# Reading kmeans output From Disk- start with the 13 clusters we discovered from clustering our PCA results
spotify = pd.read_csv((working_dir)+"/Data/spotify-classlabels-kmeans.csv", delimiter = ",")

# %% [markdown]
# # First we will develop a KNN classifier based on our cluster data set where we used PCA and Kmeans. Class labels are the cluster numbers.

# %%
target_labels = spotify['cluster']
spotify = spotify.drop(columns=['cluster'])

spotify
# Out:
#                                    artists                      id  \
# 0                          ['Mamie Smith']  0cS0A1fUEUd1EW3FcF8AEI
# 1                ["Screamin' Jay Hawkins"]  0hbkKFIJm7Z05H8Zl9w30f
# 2                          ['Mamie Smith']  11m7laMUgmOKqI3oYzuhne
# 3                      ['Oscar Velazquez']  19Lc5SfJJ5O1oaxY0fpwfh
# 4                                 ['Mixe']  2hJjbsLCytGsnAHfdsLejp
# ...                                    ...                     ...
# 174384  ['DJ Combo', 'Sander-7', 'Tony T']  46LhBf6TvYjZU2SMvGZAbn
# 174385                    ['Alessia Cara']  7tue2Wemjd0FZzRtDrQFZd
# 174386                       ['Roger Fly']  48Qj61hOdYmUCFJbpQ29Ob
# 174387                    ['Taylor Swift']  1gcyHQpBQ1lfXGdhZmWrHP
# 174388                       ['Roger Fly']  57tgYkWQTNHVFEt6xDKKZj
#
#                                                      name   year  mode_0  \
# 0                                Keep A Song In Your Soul  1920s       1
# 1                                    I Put A Spell On You  1920s       1
# 2                                            Golfing Papa  1920s       0
# 3       True House Music - Xavier Santos & Carlos Gomi...  1920s       0
# 4                                               Xuniverxe  1920s       1
# ...                                                   ...    ...     ...
# 174384                                            The One  2020s       1
# 174385                                      A Little More  2020s       0
# 174386                                           Together  2020s       1
# 174387                                 champagne problems  2020s       0
# 174388                                     Improvisations  2020s       0
#
#         acousticness  explicit_1  instrumentalness       key  valence
# 0           0.991000           0          0.000522  0.454545   0.6340
# 1           0.643000           0          0.026400  0.454545   0.9500
# 2           0.993000           0          0.000018  0.000000   0.6890
# 3           0.000173           0          0.801000  0.181818   0.0422
# 4           0.295000           1          0.000246  0.909091   0.2990
# ...              ...         ...               ...       ...      ...
# 174384      0.009170           0          0.000060  0.545455   0.1860
# 174385      0.795000           0          0.000000  0.363636   0.2280
# 174386      0.806000           0          0.920000  0.363636   0.7140
# 174387      0.920000           1          0.000000  0.000000   0.3200
# 174388      0.239000           0          0.891000  0.636364   0.7470
#
# [174389 rows x 10 columns]

# %%
train, test, target_train, target_test = train_test_split(spotify, target_labels, test_size=0.2, random_state=33)

# %%
pca_names = np.array(
    ['mode_0', 
     'acousticness', 
     'explicit_1', 
     'instrumentalness', 
     'key', 
     'valence'])
train_numeric = train[pca_names]

test_numeric = test[pca_names]

# %% [markdown]
# ### Run the classifier against different Ks, put accuracies in Dataframe and write to disk.

# %%
#find best k for knn

df_k_accuracies_highest = pd.DataFrame(columns=['K','Accuracy'])

for n in range(30, 55):
    n_neighbors = n
    knn_classifier = neighbors.KNeighborsClassifier(n_neighbors)
    knn_classifier.fit(train_numeric, target_train)

    acc = knn_classifier.score(test_numeric, target_test)
    
    df_k_accuracies_highest = df_k_accuracies_highest.append({'K': n, 'Accuracy': acc}, ignore_index=True)
    
    print(f'acc for k={n}: {acc}')
# Out:
# acc for k=30: 0.9924594300131888
# acc for k=31: 0.9925741154882735
# acc for k=32: 0.9925454441195023
# acc for k=33: 0.9924307586444177
# acc for k=34: 0.9922300590630196
# acc for k=35: 0.9923734159068754
# acc for k=36: 0.9923447445381043
# acc for k=37: 0.9926027868570445
# acc for k=38: 0.992287401800562
# acc for k=39: 0.9922300590630196
# acc for k=40: 0.9922013876942485
# acc for k=41: 0.9922587304317908
# acc for k=42: 0.9919720167440793
# acc for k=43: 0.9922300590630196
# acc for k=44: 0.9923447445381043
# acc for k=45: 0.9924020872756465
# acc for k=46: 0.9921440449567063
# acc for k=47: 0.9918860026377659
# acc for k=48: 0.9916853030563679
# acc for k=49: 0.9919433453753083
# acc for k=50: 0.9919433453753083
# acc for k=51: 0.9920293594816216
# acc for k=52: 0.9921153735879351
# acc for k=53: 0.9922300590630196
# acc for k=54: 0.9919433453753083

# %%
df_k_accuracies = df_k_accuracies.append(df_k_accuracies_highest)
df_k_accuracies = df_k_accuracies.sort_values('Accuracy', ascending=False).nlargest(50, 'Accuracy')
df_k_accuracies
# Out:
#        K  Accuracy
# 7   37.0  0.992603
# 1   31.0  0.992574
# 2   32.0  0.992545
# 3   24.0  0.992517
# 0   30.0  0.992459
# 3   33.0  0.992431
# 5   26.0  0.992402
# 15  45.0  0.992402
# 5   35.0  0.992373
# 14  44.0  0.992345
# 6   36.0  0.992345
# 4   25.0  0.992316
# 6   27.0  0.992287
# 8   38.0  0.992287
# 11  41.0  0.992259
# 1   22.0  0.992259
# 4   34.0  0.992230
# 7   28.0  0.992230
# 2   23.0  0.992230
# 13  43.0  0.992230
# 9   39.0  0.992230
# 23  53.0  0.992230
# 10  40.0  0.992201
# 16  46.0  0.992144
# 8   29.0  0.992115
# 22  52.0  0.992115
# 16  19.0  0.992087
# 14  17.0  0.992058
# 17  20.0  0.992029
# 21  51.0  0.992029
# 0   21.0  0.992001
# 12  42.0  0.991972
# 19  49.0  0.991943
# 20  50.0  0.991943
# 24  54.0  0.991943
# 13  16.0  0.991886
# 17  47.0  0.991886
# 15  18.0  0.991771
# 18  48.0  0.991685
# 12  15.0  0.991685
# 10  13.0  0.991657
# 2    5.0  0.991485
# 6    9.0  0.991485
# 9   12.0  0.991399
# 4    7.0  0.991399
# 11  14.0  0.991341
# 0    3.0  0.991198
# 7   10.0  0.990969
# 8   11.0  0.990940
# 5    8.0  0.990883

# %%
#write k values to disk

df_k_accuracies.to_csv((working_dir)+"/Data/knn-1.csv",index = False)

# %% [markdown]
# ## From running the accuracies we find a K of 37 to be the best for our PCA-kmeans clusters dataset

# %% [markdown]
# ### Next, we will walk through an instance of classifying a sample to find the cluster with our best K of 37, then using that to get more instances of the same cluster for playlist generation. This is a prototype for what will later be implemented in app.py

# %%
n_neighbors = 37
knn_classifier = neighbors.KNeighborsClassifier(n_neighbors)
knn_classifier.fit(train_numeric, target_train)
# Out:
# KNeighborsClassifier(n_neighbors=37)

# %%
test_sample_full = test.sample(1)
test_sample = test_sample_full[pca_names]

prediction = knn_classifier.predict(test_sample)
print(prediction)
# Out:
# [7]

# %%
spotify = pd.read_csv((working_dir)+"/Data/spotify-classlabels-kmeans.csv", delimiter = ",")

# %%
playlist = spotify.loc[spotify['cluster'] == prediction[0]].sample(20)
playlist
# Out:
#                                                   artists  \
# 80518   ['Richard Wagner', 'Josef Greindl', 'Philharmo...
# 156961                                    ['Frank Ocean']
# 61418                                       ['Rajkumari']
# 68715            ['Johann Sebastian Bach', 'Glenn Gould']
# 43760           ['Felix Mendelssohn', 'Arturo Toscanini']
# 129686  ['Johannes Brahms', 'Herbert von Karajan', 'Ph...
# 86910                              ['Rob Whitesides-Woo']
# 160397                                ['Lata Mangeshkar']
# 154293                  ['Franz Liszt', 'Philip Thomson']
# 2736                 ['Francisco Canaro', 'Ernesto Fama']
# 98014                               ['Barry Harris Trio']
# 69520                                       ['Brian Eno']
# 173906                            ['Oriental Music Zone']
# 110263                        ['Light Jazz Coffee House']
# 44369                ['Franz Liszt', 'Arthur Rubinstein']
# 113116                    ['Percy Faith & His Orchestra']
# 22386   ['Wolfgang Amadeus Mozart', 'Karl Böhm', 'Staa...
# 146697                                 ['Oscar Peterson']
# 88173                                     ['Alan Menken']
# 40579                                   ['Indubala Devi']
#
#                             id  \
# 80518   0TaHJD1g6zUjsq7G9MFLm3
# 156961  0GAE689kVy7sFT2QWZH1Xa
# 61418   7I2ruUPSZlvX3WGPwGFkqq
# 68715   7gAYYUV8mC5Vfsp825sqiS
# 43760   1tob591iJj5K6IpeC2V7Zc
# 129686  1jukvC9dcM8oSXH1yhycT0
# 86910   7lxjfrhWFOaOOTRF0KK8F5
# 160397  2kD3Q8qaFOPNbqrafVHJ1z
# 154293  72avKXjk0UTESGbVsxmjwG
# 2736    0Zss1Cp31Mkd4Qa0eZYw51
# 98014   0NmO85fp4esVv3Hlk2ZUDm
# 69520   4t3Yh6tKkxXrc458pNI7zZ
# 173906  6NYGY3WFmUpWizFMVSPpZZ
# 110263  11YQFXOGN1ziT5WGCoqcSw
# 44369   35uJ9mGD5agKFBFyGLB5Eb
# 113116  19kBAu9jwKvuZvE62I5wyy
# 22386   0ZqScSaqhRAEUqNBMYlCPJ
# 146697  1aUesxr5RrggibYASIgweS
# 88173   2k0uuop6Kik4p4tswCUruW
# 40579   3yyX8fk1lCsB862B8f5ddh
#
#                                                      name   year  mode_0  \
# 80518   Wagner: Tristan und Isolde, WWV 90, Act 3 Scen...  1950s       0
# 156961                                              Start  2010s       0
# 61418                Jo Ham Pe Guzarti Hai (From "Panna")  1940s       0
# 68715   Goldberg Variations, BWV 988: Variation 12 Can...  1980s       0
# 43760   Octet in E-Flat Major, Op. 20: Scherzo. Allegr...  1940s       0
# 129686  Brahms: Symphony No. 1 in C Minor, Op. 68: IV....  1950s       0
# 86910                                         Cradle Song  1980s       0
# 160397                                       Dard-E-Jigar  1950s       0
# 154293   Consolations, S172/R12: No. 2. Un poco piu mosso  1990s       0
# 2736                     Justicia Baturra - Remasterizado  1930s       0
# 98014                              All The Things You Are  1950s       0
# 69520          Thursday Afternoon - 2005 Digital Remaster  1980s       0
# 173906                                 The New Year's Eve  2010s       0
# 110263  Astounding Jazz Piano Solo - Vibe for New Year...  2020s       0
# 44369                        Mephisto Waltz No. 1, S. 514  1950s       0
# 113116                                  One Night of Love  1950s       0
# 22386   Mozart: Horn Concerto No. 3 in E-Flat Major, K...  1930s       0
# 146697                                      I Won't Dance  1950s       0
# 88173     To The Fair - From "Beauty and the Beast"/Score  1990s       0
# 40579                                       Bou Katha Kao  1930s       0
#
#         acousticness  explicit_1  instrumentalness       key  valence  cluster
# 80518          0.913           0             0.663  0.636364   0.0388        7
# 156961         0.740           0             0.931  0.636364   0.0316        7
# 61418          0.995           0             0.911  0.545455   0.7570        7
# 68715          0.984           0             0.821  0.636364   0.9750        7
# 43760          0.779           0             0.945  0.636364   0.5590        7
# 129686         0.961           0             0.914  0.000000   0.0589        7
# 86910          0.967           0             0.915  0.000000   0.3060        7
# 160397         0.993           0             0.946  1.000000   0.4020        7
# 154293         0.992           0             0.795  1.000000   0.0395        7
# 2736           0.995           0             0.907  0.181818   0.5300        7
# 98014          0.922           0             0.904  0.727273   0.3660        7
# 69520          0.976           0             0.884  0.000000   0.0528        7
# 173906         0.943           0             0.881  0.818182   0.0481        7
# 110263         0.975           0             0.884  0.454545   0.1290        7
# 44369          0.991           0             0.890  0.363636   0.0482        7
# 113116         0.652           0             0.875  0.000000   0.2020        7
# 22386          0.973           0             0.829  0.272727   0.6900        7
# 146697         0.878           0             0.843  0.000000   0.5550        7
# 88173          0.928           0             0.797  0.636364   0.3820        7
# 40579          0.995           0             0.936  0.000000   0.4870        7

# %%
test_sample_full
# Out:
#                   artists                      id  \
# 8711  ['Thelonious Monk']  6kLp24Op7cOu8iQkU46sBv
#
#                                   name   year  mode_0  acousticness  \
# 8711  I'm Confessin' (That I Love You)  1960s       0         0.965
#
#       explicit_1  instrumentalness       key  valence
# 8711           0             0.905  0.090909    0.206

# %% [markdown]
# ## Now finding our next KNN classifier for the non-pca cluster set, where there are 3 main clusters

# %%
spotify = pd.read_csv((working_dir)+"/Data/spotify-classlabels-kmeans-without_pca.csv", delimiter = ",")
spotify
# Out:
#         acousticness                             artists  danceability  \
# 0           0.991000                     ['Mamie Smith']         0.598
# 1           0.643000           ["Screamin' Jay Hawkins"]         0.852
# 2           0.993000                     ['Mamie Smith']         0.647
# 3           0.000173                 ['Oscar Velazquez']         0.730
# 4           0.295000                            ['Mixe']         0.704
# ...              ...                                 ...           ...
# 174384      0.009170  ['DJ Combo', 'Sander-7', 'Tony T']         0.792
# 174385      0.795000                    ['Alessia Cara']         0.429
# 174386      0.806000                       ['Roger Fly']         0.671
# 174387      0.920000                    ['Taylor Swift']         0.462
# 174388      0.239000                       ['Roger Fly']         0.677
#
#         duration_ms  energy                      id  instrumentalness  \
# 0          0.030637   0.224  0cS0A1fUEUd1EW3FcF8AEI          0.000522
# 1          0.027237   0.517  0hbkKFIJm7Z05H8Zl9w30f          0.026400
# 2          0.029792   0.186  11m7laMUgmOKqI3oYzuhne          0.000018
# 3          0.078215   0.798  19Lc5SfJJ5O1oaxY0fpwfh          0.801000
# 4          0.030054   0.707  2hJjbsLCytGsnAHfdsLejp          0.000246
# ...             ...     ...                     ...               ...
# 174384     0.026752   0.866  46LhBf6TvYjZU2SMvGZAbn          0.000060
# 174385     0.026209   0.211  7tue2Wemjd0FZzRtDrQFZd          0.000000
# 174386     0.039977   0.589  48Qj61hOdYmUCFJbpQ29Ob          0.920000
# 174387     0.044824   0.240  1gcyHQpBQ1lfXGdhZmWrHP          0.000000
# 174388     0.036145   0.460  57tgYkWQTNHVFEt6xDKKZj          0.891000
#
#              key  liveness  loudness  ... popularity  speechiness     tempo  \
# 0       0.454545    0.3790  0.741868  ...       0.12       0.0936  0.615900
# 1       0.454545    0.0809  0.825918  ...       0.07       0.0534  0.356823
# 2       0.000000    0.5190  0.750168  ...       0.04       0.1740  0.400810
# 3       0.181818    0.1280  0.825135  ...       0.17       0.0425  0.525640
# 4       0.909091    0.4020  0.845102  ...       0.02       0.0768  0.501324
# ...          ...       ...       ...  ...        ...          ...       ...
# 174384  0.545455    0.1780  0.859933  ...       0.00       0.0356  0.517324
# 174385  0.363636    0.1960  0.756949  ...       0.00       0.0360  0.388942
# 174386  0.363636    0.1130  0.745549  ...       0.00       0.0282  0.443757
# 174387  0.000000    0.1130  0.750497  ...       0.69       0.0377  0.703549
# 174388  0.636364    0.2150  0.747992  ...       0.00       0.0258  0.460800
#
#         valence   year explicit_0  explicit_1  mode_0  mode_1  cluster
# 0        0.6340  1920s          1           0       1       0        2
# 1        0.9500  1920s          1           0       1       0        2
# 2        0.6890  1920s          1           0       0       1        1
# 3        0.0422  1920s          1           0       0       1        0
# 4        0.2990  1920s          0           1       1       0        2
# ...         ...    ...        ...         ...     ...     ...      ...
# 174384   0.1860  2020s          1           0       1       0        2
# 174385   0.2280  2020s          1           0       0       1        1
# 174386   0.7140  2020s          1           0       1       0        2
# 174387   0.3200  2020s          0           1       0       1        1
# 174388   0.7470  2020s          1           0       0       1        0
#
# [174389 rows x 21 columns]

# %%
target_labels = spotify['cluster']
spotify = spotify.drop(columns=['cluster'])

# %%
train, test, target_train, target_test = train_test_split(spotify, target_labels, test_size=0.2, random_state=33)

# %%
#drop the non-numeric attrs
train = train.drop(columns=['artists', 'id', 'name', 'year'])
test = test.drop(columns=['artists', 'id', 'name', 'year'])

# %% [markdown]
# ### Similar to our last KNN classifier, we will test different Ks to find accuracies, write these findings to disk.

# %%
#find best k for knn

df_k_accuracies_highest = pd.DataFrame(columns=['K','Accuracy'])

for n in range(1, 50):
    n_neighbors = n
    knn_classifier = neighbors.KNeighborsClassifier(n_neighbors)
    knn_classifier.fit(train, target_train)

    acc = knn_classifier.score(test, target_test)
    
    df_k_accuracies_highest = df_k_accuracies_highest.append({'K': n, 'Accuracy': acc}, ignore_index=True)
    
    print(f'acc for k={n}: {acc}')
# Out:
# acc for k=1: 0.9843167612821836
# acc for k=2: 0.9829978783187109
# acc for k=3: 0.9876999827971787
# acc for k=4: 0.9871838981592981
# acc for k=5: 0.9889041802855668
# acc for k=6: 0.9885887952290843
# acc for k=7: 0.9896783072423877
# acc for k=8: 0.989534950398532
# acc for k=9: 0.98973564997993
# acc for k=10: 0.9898216640862435
# acc for k=11: 0.9900797064051838
# acc for k=12: 0.9900797064051838
# acc for k=13: 0.9903377487241241
# acc for k=14: 0.9903950914616664
# acc for k=15: 0.9908825047307759
# acc for k=16: 0.9911978897872584
# acc for k=17: 0.9910832043121739
# acc for k=18: 0.9911692184184873
# acc for k=19: 0.9914272607374276
# acc for k=20: 0.9913985893686564
# acc for k=21: 0.9914272607374276
# acc for k=22: 0.9912839038935719
# acc for k=23: 0.9908538333620047
# acc for k=24: 0.9912265611560296
# acc for k=25: 0.990911176099547
# acc for k=26: 0.9910545329434027
# acc for k=27: 0.9911405470497161
# acc for k=28: 0.991111875680945
# acc for k=29: 0.9913125752623431
# acc for k=30: 0.9911978897872584
# acc for k=31: 0.9911978897872584
# acc for k=32: 0.9911978897872584
# acc for k=33: 0.9913985893686564
# acc for k=34: 0.9912265611560296
# acc for k=35: 0.9911405470497161
# acc for k=36: 0.991111875680945
# acc for k=37: 0.9910258615746316
# acc for k=38: 0.9911692184184873
# acc for k=39: 0.9912265611560296
# acc for k=40: 0.9910545329434027
# acc for k=41: 0.9907391478869201
# acc for k=42: 0.9909685188370893
# acc for k=43: 0.9911405470497161
# acc for k=44: 0.9910832043121739
# acc for k=45: 0.9911692184184873
# acc for k=46: 0.991111875680945
# acc for k=47: 0.9910545329434027
# acc for k=48: 0.9910832043121739
# acc for k=49: 0.9911978897872584

# %%
df_k_accuracies_highest = df_k_accuracies_highest.append(df_k_accuracies_highest)
df_k_accuracies_highest = df_k_accuracies_highest.sort_values('Accuracy', ascending=False).nlargest(50, 'Accuracy')
df_k_accuracies_highest
# Out:
#        K  Accuracy
# 20  21.0  0.991427
# 20  21.0  0.991427
# 18  19.0  0.991427
# 18  19.0  0.991427
# 19  20.0  0.991399
# 32  33.0  0.991399
# 32  33.0  0.991399
# 19  20.0  0.991399
# 28  29.0  0.991313
# 28  29.0  0.991313
# 21  22.0  0.991284
# 21  22.0  0.991284
# 23  24.0  0.991227
# 33  34.0  0.991227
# 38  39.0  0.991227
# 23  24.0  0.991227
# 33  34.0  0.991227
# 38  39.0  0.991227
# 48  49.0  0.991198
# 29  30.0  0.991198
# 30  31.0  0.991198
# 48  49.0  0.991198
# 31  32.0  0.991198
# 15  16.0  0.991198
# 15  16.0  0.991198
# 29  30.0  0.991198
# 30  31.0  0.991198
# 31  32.0  0.991198
# 44  45.0  0.991169
# 37  38.0  0.991169
# 37  38.0  0.991169
# 17  18.0  0.991169
# 44  45.0  0.991169
# 17  18.0  0.991169
# 34  35.0  0.991141
# 26  27.0  0.991141
# 42  43.0  0.991141
# 34  35.0  0.991141
# 42  43.0  0.991141
# 26  27.0  0.991141
# 27  28.0  0.991112
# 35  36.0  0.991112
# 35  36.0  0.991112
# 27  28.0  0.991112
# 45  46.0  0.991112
# 45  46.0  0.991112
# 43  44.0  0.991083
# 16  17.0  0.991083
# 16  17.0  0.991083
# 47  48.0  0.991083

# %%
#write k values to disk

df_k_accuracies_highest.to_csv((working_dir)+"/Data/knn-2.csv",index = False)

# %% [markdown]
# ### This notebook has shown that effective KNN classifiers can be developed using our clusters found from previous experiments. The first KNN was using our PCA-Kmeans clusters, and the most effective K was 37. The second KNN classifier was with all features and clusters using Kmeans, and the best K was found to be 21. KNN with our DBSCAN or HAC clusters will not be implemented for this project.
