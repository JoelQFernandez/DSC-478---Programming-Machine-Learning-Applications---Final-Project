# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.preprocessing import StandardScaler

# %%
url = 'https://raw.githubusercontent.com/JoelQFernandez/DSC-478---Programming-Machine-Learning-Applications---Final-Project/main/Data/spotify-pca.csv'
spotify = pd.read_csv(url)
spotify
# Out:
#                                    artists                      id  \
# 0                          ['Mamie Smith']  0cS0A1fUEUd1EW3FcF8AEI
# 1                ["Screamin' Jay Hawkins"]  0hbkKFIJm7Z05H8Zl9w30f
# 2                          ['Mamie Smith']  11m7laMUgmOKqI3oYzuhne
# 3                      ['Oscar Velazquez']  19Lc5SfJJ5O1oaxY0fpwfh
# 4                                 ['Mixe']  2hJjbsLCytGsnAHfdsLejp
# ...                                    ...                     ...
# 174384  ['DJ Combo', 'Sander-7', 'Tony T']  46LhBf6TvYjZU2SMvGZAbn
# 174385                    ['Alessia Cara']  7tue2Wemjd0FZzRtDrQFZd
# 174386                       ['Roger Fly']  48Qj61hOdYmUCFJbpQ29Ob
# 174387                    ['Taylor Swift']  1gcyHQpBQ1lfXGdhZmWrHP
# 174388                       ['Roger Fly']  57tgYkWQTNHVFEt6xDKKZj
#
#                                                      name   year  mode_0  \
# 0                                Keep A Song In Your Soul  1920s       1
# 1                                    I Put A Spell On You  1920s       1
# 2                                            Golfing Papa  1920s       0
# 3       True House Music - Xavier Santos & Carlos Gomi...  1920s       0
# 4                                               Xuniverxe  1920s       1
# ...                                                   ...    ...     ...
# 174384                                            The One  2020s       1
# 174385                                      A Little More  2020s       0
# 174386                                           Together  2020s       1
# 174387                                 champagne problems  2020s       0
# 174388                                     Improvisations  2020s       0
#
#         acousticness  explicit_0  instrumentalness       key  valence
# 0           0.991000           1          0.000522  0.454545   0.6340
# 1           0.643000           1          0.026400  0.454545   0.9500
# 2           0.993000           1          0.000018  0.000000   0.6890
# 3           0.000173           1          0.801000  0.181818   0.0422
# 4           0.295000           0          0.000246  0.909091   0.2990
# ...              ...         ...               ...       ...      ...
# 174384      0.009170           1          0.000060  0.545455   0.1860
# 174385      0.795000           1          0.000000  0.363636   0.2280
# 174386      0.806000           1          0.920000  0.363636   0.7140
# 174387      0.920000           0          0.000000  0.000000   0.3200
# 174388      0.239000           1          0.891000  0.636364   0.7470
#
# [174389 rows x 10 columns]

# %%
# dataframe to be used for DBSCAN made up of the features from PCA dimensionality reduction
df = spotify[['mode_0',
 'acousticness',
 'explicit_0',
 'instrumentalness',
 'key',
 'valence']]
df
# Out:
#         mode_0  acousticness  explicit_0  instrumentalness       key  valence
# 0            1      0.991000           1          0.000522  0.454545   0.6340
# 1            1      0.643000           1          0.026400  0.454545   0.9500
# 2            0      0.993000           1          0.000018  0.000000   0.6890
# 3            0      0.000173           1          0.801000  0.181818   0.0422
# 4            1      0.295000           0          0.000246  0.909091   0.2990
# ...        ...           ...         ...               ...       ...      ...
# 174384       1      0.009170           1          0.000060  0.545455   0.1860
# 174385       0      0.795000           1          0.000000  0.363636   0.2280
# 174386       1      0.806000           1          0.920000  0.363636   0.7140
# 174387       0      0.920000           0          0.000000  0.000000   0.3200
# 174388       0      0.239000           1          0.891000  0.636364   0.7470
#
# [174389 rows x 6 columns]

# %%
# random sample the data
sample = df.sample(frac=0.1, random_state=2)
sample
# Out:
#         mode_0  acousticness  explicit_0  instrumentalness       key  valence
# 76727        1      0.242000           1          0.013400  0.363636   0.6170
# 159968       1      0.968000           1          0.000010  0.727273   0.5970
# 67064        1      0.709000           1          0.001340  0.363636   0.1880
# 24196        1      0.865000           1          0.061300  0.181818   0.5940
# 158015       0      0.945000           1          0.000267  0.909091   0.1860
# ...        ...           ...         ...               ...       ...      ...
# 49358        0      0.424000           1          0.001270  0.636364   0.3290
# 129420       0      0.426000           1          0.000000  0.454545   0.2830
# 138979       1      0.037800           1          0.000000  0.454545   0.6120
# 3900         0      0.952000           1          0.938000  0.000000   0.0469
# 153923       0      0.000306           1          0.580000  1.000000   0.7810
#
# [17439 rows x 6 columns]

# %%
# Compute DBSCAN
db = DBSCAN(eps=.5, min_samples=10).fit(sample)
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_

# %%
# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)
sil = metrics.silhouette_score(sample, labels)

# %%
#Print Values
print('Estimated number of clusters: %d' % n_clusters_)
print('Estimated number of noise points: %d' % n_noise_)
print("Silhouette Coefficient: %0.3f" % sil)
# Out:
# Estimated number of clusters: 4
# Estimated number of noise points: 43
# Silhouette Coefficient: 0.334
